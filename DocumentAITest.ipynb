# %%
from google.cloud import documentai_v1beta3 as documentai

# %%
# !pip install --upgrade google-cloud-documentai
# Out:
# Requirement already up-to-date: google-cloud-documentai in c:\users\srengaraman\machinelearning\env\lib\site-packages (0.3.0)
# Requirement already satisfied, skipping upgrade: proto-plus>=1.10.0 in c:\users\srengaraman\machinelearning\env\lib\site-packages (from google-cloud-documentai) (1.11.0)
# Requirement already satisfied, skipping upgrade: google-api-core[grpc]<2.0.0dev,>=1.22.0 in c:\users\srengaraman\machinelearning\env\lib\site-packages (from google-cloud-documentai) (1.23.0)
# Requirement already satisfied, skipping upgrade: protobuf>=3.12.0 in c:\users\srengaraman\machinelearning\env\lib\site-packages (from proto-plus>=1.10.0->google-cloud-documentai) (3.12.2)
# Requirement already satisfied, skipping upgrade: google-auth<2.0dev,>=1.21.1 in c:\users\srengaraman\machinelearning\env\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.22.0->google-cloud-documentai) (1.23.0)
# Requirement already satisfied, skipping upgrade: requests<3.0.0dev,>=2.18.0 in c:\users\srengaraman\machinelearning\env\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.22.0->google-cloud-documentai) (2.24.0)
# Requirement already satisfied, skipping upgrade: setuptools>=34.0.0 in c:\users\srengaraman\machinelearning\env\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.22.0->google-cloud-documentai) (46.1.3.post20200330)
# Requirement already satisfied, skipping upgrade: googleapis-common-protos<2.0dev,>=1.6.0 in c:\users\srengaraman\machinelearning\env\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.22.0->google-cloud-documentai) (1.52.0)
# Requirement already satisfied, skipping upgrade: pytz in c:\users\srengaraman\machinelearning\env\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.22.0->google-cloud-documentai) (2019.3)
# Requirement already satisfied, skipping upgrade: six>=1.13.0 in c:\users\srengaraman\machinelearning\env\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.22.0->google-cloud-documentai) (1.14.0)
# Requirement already satisfied, skipping upgrade: grpcio<2.0dev,>=1.29.0; extra == "grpc" in c:\users\srengaraman\machinelearning\env\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.22.0->google-cloud-documentai) (1.30.0)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in c:\users\srengaraman\machinelearning\env\lib\site-packages (from google-auth<2.0dev,>=1.21.1->google-api-core[grpc]<2.0.0dev,>=1.22.0->google-cloud-documentai) (0.2.8)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3.5" in c:\users\srengaraman\machinelearning\env\lib\site-packages (from google-auth<2.0dev,>=1.21.1->google-api-core[grpc]<2.0.0dev,>=1.22.0->google-cloud-documentai) (4.6)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in c:\users\srengaraman\machinelearning\env\lib\site-packages (from google-auth<2.0dev,>=1.21.1->google-api-core[grpc]<2.0.0dev,>=1.22.0->google-cloud-documentai) (4.1.0)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in c:\users\srengaraman\machinelearning\env\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.22.0->google-cloud-documentai) (2.9)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in c:\users\srengaraman\machinelearning\env\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.22.0->google-cloud-documentai) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\srengaraman\machinelearning\env\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.22.0->google-cloud-documentai) (1.25.9)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\srengaraman\machinelearning\env\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.22.0->google-cloud-documentai) (2020.6.20)
# Requirement already satisfied, skipping upgrade: pyasn1<0.5.0,>=0.4.6 in c:\users\srengaraman\machinelearning\env\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.21.1->google-api-core[grpc]<2.0.0dev,>=1.22.0->google-cloud-documentai) (0.4.8)

# %%
project_id= 'upbeat-nation-288816'
location = 'us' # Format is 'us' or 'eu'
processor_id = 'b9d997bc8b305c55' #  Create processor in Cloud Console
file_path = r'C:\Users\srengaraman\Personal\BOL_Sample.pdf'


def quickstart(project_id: str, location: str, processor_id: str, file_path: str):
    client = documentai.DocumentProcessorServiceClient.from_service_account_json(r"C:\Users\srengaraman\Personal\GCP\ProjectViveka-0f5571ed2a4b.json")
    
    # The full resource name of the processor, e.g.:
    # projects/project-id/locations/location/processor/processor-id
    # You must create new processors in the Cloud Console first
    name = f"projects/{project_id}/locations/{location}/processors/{processor_id}"

    # Read the file into memory
    with open(file_path, "rb") as image:
        image_content = image.read()

    document = {"content": image_content, "mime_type": "application/pdf"}

    # Configure the process request
    request = {"name": name, "document": document}

    result = client.process_document(request=request)
    document = result.document

    document_pages = document.pages

    # For a full list of Document object attributes, please reference this page: https://googleapis.dev/python/documentai/latest/_modules/google/cloud/documentai_v1beta3/types/document.html#Document

    # Read the text recognition output from the processor
    print("The document contains the following paragraphs:")
    for page in document_pages:
        paragraphs = page.paragraphs
        for paragraph in paragraphs:
            print(paragraph)
            paragraph_text = get_text(paragraph.layout, document)
            print(f"Paragraph text: {paragraph_text}")
            
# Extract shards from the text field
def get_text(doc_element: dict, document: dict):
    """
    Document AI identifies form fields by their offsets
    in document text. This function converts offsets
    to text snippets.
    """
    response = ""
    # If a text segment spans several lines, it will
    # be stored in different text segments.
    for segment in doc_element.text_anchor.text_segments:
        start_index = (
            int(segment.start_index)
            if segment in doc_element.text_anchor.text_segments
            else 0
        )
        end_index = int(segment.end_index)
        response += document.text[start_index:end_index]
    return response


quickstart(project_id, location, processor_id, file_path)
# Out:
# The document contains the following paragraphs:
# layout {
#   text_anchor {
#     text_segments {
#       end_index: 244
#     }
#   }
#   confidence: 0.983739
#   bounding_poly {
#     vertices {
#       x: 175
#       y: 62
#     }
#     vertices {
#       x: 1341
#       y: 61
#     }
#     vertices {
#       x: 1341
#       y: 238
#     }
#     vertices {
#       x: 175
#       y: 239
#     }
#     normalized_vertices {
#       x: 0.099544935
#       y: 0.027252747
#     }
#     normalized_vertices {
#       x: 0.7627986
#       y: 0.026813187
#     }
#     normalized_vertices {
#       x: 0.7627986
#       y: 0.10461538
#     }
#     normalized_vertices {
#       x: 0.099544935
#       y: 0.105054945
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: 04/07/2016STRAIGHT BILL OF LADINGCarrier NamePurchase Order NumberShipment NumberCON-WAY TRANSPORTATION137413930D000BK150095 (MULTIPLE)CS00068390SERVICES, INC.Shipper (from)Consignee (to)Name BALKAMP, INC Plainfield.Name CANDELA AUTO PARTS INC
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 244
#       end_index: 273
#     }
#   }
#   confidence: 0.9922663
#   bounding_poly {
#     vertices {
#       x: 1370
#       y: 100
#     }
#     vertices {
#       x: 1581
#       y: 100
#     }
#     vertices {
#       x: 1581
#       y: 160
#     }
#     vertices {
#       x: 1370
#       y: 160
#     }
#     normalized_vertices {
#       x: 0.77929467
#       y: 0.043956045
#     }
#     normalized_vertices {
#       x: 0.8993174
#       y: 0.043956045
#     }
#     normalized_vertices {
#       x: 0.8993174
#       y: 0.07032967
#     }
#     normalized_vertices {
#       x: 0.77929467
#       y: 0.07032967
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: Bill of Lading Number1022536
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 273
#       end_index: 290
#     }
#   }
#   confidence: 0.99203247
#   bounding_poly {
#     vertices {
#       x: 321
#       y: 285
#     }
#     vertices {
#       x: 492
#       y: 285
#     }
#     vertices {
#       x: 492
#       y: 306
#     }
#     vertices {
#       x: 321
#       y: 306
#     }
#     normalized_vertices {
#       x: 0.18259385
#       y: 0.12527473
#     }
#     normalized_vertices {
#       x: 0.27986348
#       y: 0.12527473
#     }
#     normalized_vertices {
#       x: 0.27986348
#       y: 0.1345055
#     }
#     normalized_vertices {
#       x: 0.18259385
#       y: 0.1345055
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: 1601 Whitaker Rd
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 290
#       end_index: 316
#     }
#   }
#   confidence: 0.99441135
#   bounding_poly {
#     vertices {
#       x: 1046
#       y: 285
#     }
#     vertices {
#       x: 1383
#       y: 285
#     }
#     vertices {
#       x: 1383
#       y: 307
#     }
#     vertices {
#       x: 1046
#       y: 307
#     }
#     normalized_vertices {
#       x: 0.5949943
#       y: 0.12527473
#     }
#     normalized_vertices {
#       x: 0.7866894
#       y: 0.12527473
#     }
#     normalized_vertices {
#       x: 0.7866894
#       y: 0.13494505
#     }
#     normalized_vertices {
#       x: 0.5949943
#       y: 0.13494505
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: 2713B SOUTH WOODLAND BLVD
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 316
#       end_index: 328
#     }
#   }
#   confidence: 0.995429
#   bounding_poly {
#     vertices {
#       x: 195
#       y: 287
#     }
#     vertices {
#       x: 273
#       y: 288
#     }
#     vertices {
#       x: 272
#       y: 343
#     }
#     vertices {
#       x: 194
#       y: 342
#     }
#     normalized_vertices {
#       x: 0.1109215
#       y: 0.12615384
#     }
#     normalized_vertices {
#       x: 0.1552901
#       y: 0.12659341
#     }
#     normalized_vertices {
#       x: 0.15472127
#       y: 0.15076923
#     }
#     normalized_vertices {
#       x: 0.11035267
#       y: 0.15032966
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: AddressCity
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 328
#       end_index: 339
#     }
#   }
#   confidence: 0.9934594
#   bounding_poly {
#     vertices {
#       x: 321
#       y: 321
#     }
#     vertices {
#       x: 402
#       y: 321
#     }
#     vertices {
#       x: 402
#       y: 340
#     }
#     vertices {
#       x: 321
#       y: 340
#     }
#     normalized_vertices {
#       x: 0.18259385
#       y: 0.1410989
#     }
#     normalized_vertices {
#       x: 0.22866894
#       y: 0.1410989
#     }
#     normalized_vertices {
#       x: 0.22866894
#       y: 0.14945056
#     }
#     normalized_vertices {
#       x: 0.18259385
#       y: 0.14945056
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: Plainfield
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 339
#       end_index: 357
#     }
#   }
#   confidence: 0.9933162
#   bounding_poly {
#     vertices {
#       x: 615
#       y: 321
#     }
#     vertices {
#       x: 779
#       y: 321
#     }
#     vertices {
#       x: 779
#       y: 341
#     }
#     vertices {
#       x: 615
#       y: 341
#     }
#     normalized_vertices {
#       x: 0.34982935
#       y: 0.1410989
#     }
#     normalized_vertices {
#       x: 0.44311717
#       y: 0.1410989
#     }
#     normalized_vertices {
#       x: 0.44311717
#       y: 0.14989011
#     }
#     normalized_vertices {
#       x: 0.34982935
#       y: 0.14989011
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: State or Province
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 357
#       end_index: 360
#     }
#   }
#   confidence: 0.9929011
#   bounding_poly {
#     vertices {
#       x: 810
#       y: 320
#     }
#     vertices {
#       x: 823
#       y: 320
#     }
#     vertices {
#       x: 823
#       y: 339
#     }
#     vertices {
#       x: 810
#       y: 339
#     }
#     normalized_vertices {
#       x: 0.46075085
#       y: 0.14065935
#     }
#     normalized_vertices {
#       x: 0.4681456
#       y: 0.14065935
#     }
#     normalized_vertices {
#       x: 0.4681456
#       y: 0.14901099
#     }
#     normalized_vertices {
#       x: 0.46075085
#       y: 0.14901099
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: IN
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 360
#       end_index: 375
#     }
#   }
#   confidence: 0.9938132
#   bounding_poly {
#     vertices {
#       x: 932
#       y: 286
#     }
#     vertices {
#       x: 1013
#       y: 288
#     }
#     vertices {
#       x: 1010
#       y: 379
#     }
#     vertices {
#       x: 929
#       y: 377
#     }
#     normalized_vertices {
#       x: 0.5301479
#       y: 0.12571429
#     }
#     normalized_vertices {
#       x: 0.57622296
#       y: 0.12659341
#     }
#     normalized_vertices {
#       x: 0.5745165
#       y: 0.1665934
#     }
#     normalized_vertices {
#       x: 0.5284414
#       y: 0.16571428
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: AddressCityZip
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 375
#       end_index: 382
#     }
#   }
#   confidence: 0.99373937
#   bounding_poly {
#     vertices {
#       x: 1045
#       y: 320
#     }
#     vertices {
#       x: 1130
#       y: 321
#     }
#     vertices {
#       x: 1130
#       y: 340
#     }
#     vertices {
#       x: 1045
#       y: 339
#     }
#     normalized_vertices {
#       x: 0.5944255
#       y: 0.14065935
#     }
#     normalized_vertices {
#       x: 0.6427759
#       y: 0.1410989
#     }
#     normalized_vertices {
#       x: 0.6427759
#       y: 0.14945056
#     }
#     normalized_vertices {
#       x: 0.5944255
#       y: 0.14901099
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: DELAND
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 382
#       end_index: 403
#     }
#   }
#   confidence: 0.99378675
#   bounding_poly {
#     vertices {
#       x: 1313
#       y: 321
#     }
#     vertices {
#       x: 1521
#       y: 320
#     }
#     vertices {
#       x: 1521
#       y: 340
#     }
#     vertices {
#       x: 1313
#       y: 341
#     }
#     normalized_vertices {
#       x: 0.7468715
#       y: 0.1410989
#     }
#     normalized_vertices {
#       x: 0.8651877
#       y: 0.14065935
#     }
#     normalized_vertices {
#       x: 0.8651877
#       y: 0.14945056
#     }
#     normalized_vertices {
#       x: 0.7468715
#       y: 0.14989011
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: State or Province FL
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 403
#       end_index: 407
#     }
#   }
#   confidence: 0.98937416
#   bounding_poly {
#     vertices {
#       x: 202
#       y: 356
#     }
#     vertices {
#       x: 227
#       y: 358
#     }
#     vertices {
#       x: 225
#       y: 381
#     }
#     vertices {
#       x: 200
#       y: 379
#     }
#     normalized_vertices {
#       x: 0.1149033
#       y: 0.15648352
#     }
#     normalized_vertices {
#       x: 0.129124
#       y: 0.15736264
#     }
#     normalized_vertices {
#       x: 0.12798634
#       y: 0.16747253
#     }
#     normalized_vertices {
#       x: 0.11376564
#       y: 0.1665934
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: Zip
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 407
#       end_index: 413
#     }
#   }
#   confidence: 0.99348766
#   bounding_poly {
#     vertices {
#       x: 322
#       y: 356
#     }
#     vertices {
#       x: 379
#       y: 356
#     }
#     vertices {
#       x: 379
#       y: 377
#     }
#     vertices {
#       x: 322
#       y: 377
#     }
#     normalized_vertices {
#       x: 0.18316269
#       y: 0.15648352
#     }
#     normalized_vertices {
#       x: 0.21558589
#       y: 0.15648352
#     }
#     normalized_vertices {
#       x: 0.21558589
#       y: 0.16571428
#     }
#     normalized_vertices {
#       x: 0.18316269
#       y: 0.16571428
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: 46168
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 413
#       end_index: 419
#     }
#   }
#   confidence: 0.9942771
#   bounding_poly {
#     vertices {
#       x: 1048
#       y: 357
#     }
#     vertices {
#       x: 1103
#       y: 358
#     }
#     vertices {
#       x: 1103
#       y: 378
#     }
#     vertices {
#       x: 1048
#       y: 377
#     }
#     normalized_vertices {
#       x: 0.596132
#       y: 0.15692307
#     }
#     normalized_vertices {
#       x: 0.6274175
#       y: 0.15736264
#     }
#     normalized_vertices {
#       x: 0.6274175
#       y: 0.16615385
#     }
#     normalized_vertices {
#       x: 0.596132
#       y: 0.16571428
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: 32720
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 419
#       end_index: 499
#     }
#   }
#   confidence: 0.99241245
#   bounding_poly {
#     vertices {
#       x: 171
#       y: 405
#     }
#     vertices {
#       x: 754
#       y: 405
#     }
#     vertices {
#       x: 754
#       y: 427
#     }
#     vertices {
#       x: 171
#       y: 427
#     }
#     normalized_vertices {
#       x: 0.097269624
#       y: 0.17802198
#     }
#     normalized_vertices {
#       x: 0.4288965
#       y: 0.17802198
#     }
#     normalized_vertices {
#       x: 0.4288965
#       y: 0.18769231
#     }
#     normalized_vertices {
#       x: 0.097269624
#       y: 0.18769231
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: Freight Charges (Note: Freight Charges are to be Prepaid unless marked collect)
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 499
#       end_index: 507
#     }
#   }
#   confidence: 0.9936914
#   bounding_poly {
#     vertices {
#       x: 910
#       y: 406
#     }
#     vertices {
#       x: 989
#       y: 407
#     }
#     vertices {
#       x: 989
#       y: 433
#     }
#     vertices {
#       x: 910
#       y: 432
#     }
#     normalized_vertices {
#       x: 0.5176337
#       y: 0.17846154
#     }
#     normalized_vertices {
#       x: 0.5625711
#       y: 0.1789011
#     }
#     normalized_vertices {
#       x: 0.5625711
#       y: 0.19032967
#     }
#     normalized_vertices {
#       x: 0.5176337
#       y: 0.18989012
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: Prepaid
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 507
#       end_index: 515
#     }
#   }
#   confidence: 0.99577314
#   bounding_poly {
#     vertices {
#       x: 1162
#       y: 405
#     }
#     vertices {
#       x: 1237
#       y: 405
#     }
#     vertices {
#       x: 1237
#       y: 428
#     }
#     vertices {
#       x: 1162
#       y: 428
#     }
#     normalized_vertices {
#       x: 0.6609784
#       y: 0.17802198
#     }
#     normalized_vertices {
#       x: 0.7036405
#       y: 0.17802198
#     }
#     normalized_vertices {
#       x: 0.7036405
#       y: 0.18813187
#     }
#     normalized_vertices {
#       x: 0.6609784
#       y: 0.18813187
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: Collect
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 515
#       end_index: 527
#     }
#   }
#   confidence: 0.9929145
#   bounding_poly {
#     vertices {
#       x: 1380
#       y: 403
#     }
#     vertices {
#       x: 1494
#       y: 408
#     }
#     vertices {
#       x: 1493
#       y: 434
#     }
#     vertices {
#       x: 1379
#       y: 429
#     }
#     normalized_vertices {
#       x: 0.7849829
#       y: 0.17714286
#     }
#     normalized_vertices {
#       x: 0.8498294
#       y: 0.17934066
#     }
#     normalized_vertices {
#       x: 0.8492605
#       y: 0.19076923
#     }
#     normalized_vertices {
#       x: 0.7844141
#       y: 0.18857142
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: Third Party
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 527
#       end_index: 537
#     }
#   }
#   confidence: 0.8821795
#   bounding_poly {
#     vertices {
#       x: 936
#       y: 452
#     }
#     vertices {
#       x: 1044
#       y: 451
#     }
#     vertices {
#       x: 1044
#       y: 473
#     }
#     vertices {
#       x: 936
#       y: 474
#     }
#     normalized_vertices {
#       x: 0.5324232
#       y: 0.19868132
#     }
#     normalized_vertices {
#       x: 0.59385663
#       y: 0.19824176
#     }
#     normalized_vertices {
#       x: 0.59385663
#       y: 0.20791209
#     }
#     normalized_vertices {
#       x: 0.5324232
#       y: 0.20835164
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: PL_INSTRC
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 537
#       end_index: 554
#     }
#   }
#   confidence: 0.9872291
#   bounding_poly {
#     vertices {
#       x: 189
#       y: 462
#     }
#     vertices {
#       x: 377
#       y: 461
#     }
#     vertices {
#       x: 377
#       y: 488
#     }
#     vertices {
#       x: 189
#       y: 489
#     }
#     normalized_vertices {
#       x: 0.10750853
#       y: 0.20307693
#     }
#     normalized_vertices {
#       x: 0.21444824
#       y: 0.20263736
#     }
#     normalized_vertices {
#       x: 0.21444824
#       y: 0.2145055
#     }
#     normalized_vertices {
#       x: 0.10750853
#       y: 0.21494505
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: ☑ Underlying_BOL
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 554
#       end_index: 567
#     }
#   }
#   confidence: 0.9921719
#   bounding_poly {
#     vertices {
#       x: 1189
#       y: 449
#     }
#     vertices {
#       x: 1513
#       y: 447
#     }
#     vertices {
#       x: 1513
#       y: 486
#     }
#     vertices {
#       x: 1189
#       y: 488
#     }
#     normalized_vertices {
#       x: 0.67633677
#       y: 0.19736263
#     }
#     normalized_vertices {
#       x: 0.86063707
#       y: 0.19648352
#     }
#     normalized_vertices {
#       x: 0.86063707
#       y: 0.21362637
#     }
#     normalized_vertices {
#       x: 0.67633677
#       y: 0.2145055
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: DO NOT STACK
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 567
#       end_index: 572
#     }
#   }
#   confidence: 0.9604426
#   bounding_poly {
#     vertices {
#       x: 915
#       y: 499
#     }
#     vertices {
#       x: 946
#       y: 500
#     }
#     vertices {
#       x: 945
#       y: 518
#     }
#     vertices {
#       x: 914
#       y: 517
#     }
#     normalized_vertices {
#       x: 0.52047783
#       y: 0.21934065
#     }
#     normalized_vertices {
#       x: 0.5381115
#       y: 0.21978022
#     }
#     normalized_vertices {
#       x: 0.53754264
#       y: 0.2276923
#     }
#     normalized_vertices {
#       x: 0.51990896
#       y: 0.22725275
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: null
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 572
#       end_index: 622
#     }
#   }
#   confidence: 0.98684627
#   bounding_poly {
#     vertices {
#       x: 187
#       y: 509
#     }
#     vertices {
#       x: 628
#       y: 509
#     }
#     vertices {
#       x: 628
#       y: 534
#     }
#     vertices {
#       x: 187
#       y: 534
#     }
#     normalized_vertices {
#       x: 0.106370874
#       y: 0.22373626
#     }
#     normalized_vertices {
#       x: 0.3572241
#       y: 0.22373626
#     }
#     normalized_vertices {
#       x: 0.3572241
#       y: 0.23472528
#     }
#     normalized_vertices {
#       x: 0.106370874
#       y: 0.23472528
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: Bill Freight charges to (if different than above)
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 622
#       end_index: 627
#     }
#   }
#   confidence: 0.9887704
#   bounding_poly {
#     vertices {
#       x: 186
#       y: 552
#     }
#     vertices {
#       x: 244
#       y: 552
#     }
#     vertices {
#       x: 244
#       y: 571
#     }
#     vertices {
#       x: 186
#       y: 571
#     }
#     normalized_vertices {
#       x: 0.105802044
#       y: 0.24263737
#     }
#     normalized_vertices {
#       x: 0.13879408
#       y: 0.24263737
#     }
#     normalized_vertices {
#       x: 0.13879408
#       y: 0.25098902
#     }
#     normalized_vertices {
#       x: 0.105802044
#       y: 0.25098902
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: Name
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 627
#       end_index: 635
#     }
#   }
#   confidence: 0.9954449
#   bounding_poly {
#     vertices {
#       x: 187
#       y: 611
#     }
#     vertices {
#       x: 266
#       y: 610
#     }
#     vertices {
#       x: 266
#       y: 630
#     }
#     vertices {
#       x: 187
#       y: 631
#     }
#     normalized_vertices {
#       x: 0.106370874
#       y: 0.26857144
#     }
#     normalized_vertices {
#       x: 0.1513083
#       y: 0.26813188
#     }
#     normalized_vertices {
#       x: 0.1513083
#       y: 0.2769231
#     }
#     normalized_vertices {
#       x: 0.106370874
#       y: 0.27736264
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: Address
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 635
#       end_index: 819
#     }
#   }
#   confidence: 0.9672517
#   bounding_poly {
#     vertices {
#       x: 164
#       y: 642
#     }
#     vertices {
#       x: 1428
#       y: 663
#     }
#     vertices {
#       x: 1426
#       y: 758
#     }
#     vertices {
#       x: 162
#       y: 737
#     }
#     normalized_vertices {
#       x: 0.093287826
#       y: 0.2821978
#     }
#     normalized_vertices {
#       x: 0.8122867
#       y: 0.29142857
#     }
#     normalized_vertices {
#       x: 0.81114906
#       y: 0.3331868
#     }
#     normalized_vertices {
#       x: 0.092150174
#       y: 0.32395604
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: City:St:Zip:PRO #: 2525258OTHER PURCHASE ORDERS: 13754817OD000BK053141, 13754901OD000BK087317, 13756792OD000BK063727, 137571690D000BK2341F, 13757753OD000BK052757,137583670D000BK189531
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 819
#       end_index: 1052
#     }
#   }
#   confidence: 0.98915553
#   bounding_poly {
#     vertices {
#       x: 459
#       y: 776
#     }
#     vertices {
#       x: 1207
#       y: 777
#     }
#     vertices {
#       x: 1207
#       y: 935
#     }
#     vertices {
#       x: 459
#       y: 934
#     }
#     normalized_vertices {
#       x: 0.26109216
#       y: 0.3410989
#     }
#     normalized_vertices {
#       x: 0.68657565
#       y: 0.34153846
#     }
#     normalized_vertices {
#       x: 0.68657565
#       y: 0.41098902
#     }
#     normalized_vertices {
#       x: 0.26109216
#       y: 0.41054946
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: Emergency Contact Number For Hazardous Materials(SPILL, LEAK, FIRE, EXPOSURE or ACCIDENT)1-800-424-9300 (Chemtrec-CCN2285)KIND OF PACKAGING DESCRIPTION OF ARTICLES WEIGHTNMClassSPECIAL MARKS AND EXCEPTIONSLBS.(SUBJECT TO CORRECTION)
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 1052
#       end_index: 1066
#     }
#   }
#   confidence: 0.99191487
#   bounding_poly {
#     vertices {
#       x: 167
#       y: 868
#     }
#     vertices {
#       x: 253
#       y: 867
#     }
#     vertices {
#       x: 253
#       y: 904
#     }
#     vertices {
#       x: 167
#       y: 905
#     }
#     normalized_vertices {
#       x: 0.094994314
#       y: 0.38153845
#     }
#     normalized_vertices {
#       x: 0.14391354
#       y: 0.3810989
#     }
#     normalized_vertices {
#       x: 0.14391354
#       y: 0.39736265
#     }
#     normalized_vertices {
#       x: 0.094994314
#       y: 0.3978022
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: HANDLINGUNITS
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 1066
#       end_index: 1077
#     }
#   }
#   confidence: 0.98260516
#   bounding_poly {
#     vertices {
#       x: 274
#       y: 869
#     }
#     vertices {
#       x: 367
#       y: 869
#     }
#     vertices {
#       x: 367
#       y: 906
#     }
#     vertices {
#       x: 274
#       y: 906
#     }
#     normalized_vertices {
#       x: 0.15585893
#       y: 0.38197803
#     }
#     normalized_vertices {
#       x: 0.20875995
#       y: 0.38197803
#     }
#     normalized_vertices {
#       x: 0.20875995
#       y: 0.39824176
#     }
#     normalized_vertices {
#       x: 0.15585893
#       y: 0.39824176
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: HMPACKAGES
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 1077
#       end_index: 1081
#     }
#   }
#   confidence: 0.8955797
#   bounding_poly {
#     vertices {
#       x: 386
#       y: 869
#     }
#     vertices {
#       x: 415
#       y: 869
#     }
#     vertices {
#       x: 415
#       y: 907
#     }
#     vertices {
#       x: 386
#       y: 907
#     }
#     normalized_vertices {
#       x: 0.21956769
#       y: 0.38197803
#     }
#     normalized_vertices {
#       x: 0.2360637
#       y: 0.38197803
#     }
#     normalized_vertices {
#       x: 0.2360637
#       y: 0.3986813
#     }
#     normalized_vertices {
#       x: 0.21956769
#       y: 0.3986813
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: HMX
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 1081
#       end_index: 1337
#     }
#   }
#   confidence: 0.9897204
#   bounding_poly {
#     vertices {
#       x: 1246
#       y: 865
#     }
#     vertices {
#       x: 1590
#       y: 865
#     }
#     vertices {
#       x: 1590
#       y: 998
#     }
#     vertices {
#       x: 1246
#       y: 998
#     }
#     normalized_vertices {
#       x: 0.70875996
#       y: 0.3802198
#     }
#     normalized_vertices {
#       x: 0.9044369
#       y: 0.3802198
#     }
#     normalized_vertices {
#       x: 0.9044369
#       y: 0.4386813
#     }
#     normalized_vertices {
#       x: 0.70875996
#       y: 0.4386813
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: Subject to Se 7 cond of applicablebill of lading. If this shipment is to be deliveredto the consignee without recourse on the thefollowing statement:The carrier shall not make delivery of thisshipment without payment of freight and II otherlawful charges.
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 1337
#       end_index: 1361
#     }
#   }
#   confidence: 0.993668
#   bounding_poly {
#     vertices {
#       x: 429
#       y: 948
#     }
#     vertices {
#       x: 624
#       y: 948
#     }
#     vertices {
#       x: 624
#       y: 962
#     }
#     vertices {
#       x: 429
#       y: 962
#     }
#     normalized_vertices {
#       x: 0.2440273
#       y: 0.41670328
#     }
#     normalized_vertices {
#       x: 0.35494882
#       y: 0.41670328
#     }
#     normalized_vertices {
#       x: 0.35494882
#       y: 0.42285714
#     }
#     normalized_vertices {
#       x: 0.2440273
#       y: 0.42285714
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: SEE ATTACHED UNDERLYING
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 1361
#       end_index: 1377
#     }
#   }
#   confidence: 0.9940695
#   bounding_poly {
#     vertices {
#       x: 428
#       y: 984
#     }
#     vertices {
#       x: 539
#       y: 984
#     }
#     vertices {
#       x: 539
#       y: 999
#     }
#     vertices {
#       x: 428
#       y: 999
#     }
#     normalized_vertices {
#       x: 0.24345848
#       y: 0.43252748
#     }
#     normalized_vertices {
#       x: 0.3065984
#       y: 0.43252748
#     }
#     normalized_vertices {
#       x: 0.3065984
#       y: 0.4391209
#     }
#     normalized_vertices {
#       x: 0.24345848
#       y: 0.4391209
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: BILLS OF LADING
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 1377
#       end_index: 1400
#     }
#   }
#   confidence: 0.9952128
#   bounding_poly {
#     vertices {
#       x: 1333
#       y: 1053
#     }
#     vertices {
#       x: 1501
#       y: 1053
#     }
#     vertices {
#       x: 1501
#       y: 1073
#     }
#     vertices {
#       x: 1333
#       y: 1073
#     }
#     normalized_vertices {
#       x: 0.75824803
#       y: 0.46285716
#     }
#     normalized_vertices {
#       x: 0.85381114
#       y: 0.46285716
#     }
#     normalized_vertices {
#       x: 0.85381114
#       y: 0.47164837
#     }
#     normalized_vertices {
#       x: 0.75824803
#       y: 0.47164837
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: Signature of Consignee
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 1400
#       end_index: 1650
#     }
#   }
#   confidence: 0.99506426
#   bounding_poly {
#     vertices {
#       x: 1244
#       y: 1095
#     }
#     vertices {
#       x: 1576
#       y: 1094
#     }
#     vertices {
#       x: 1576
#       y: 1210
#     }
#     vertices {
#       x: 1244
#       y: 1211
#     }
#     normalized_vertices {
#       x: 0.7076223
#       y: 0.48131868
#     }
#     normalized_vertices {
#       x: 0.8964733
#       y: 0.48087913
#     }
#     normalized_vertices {
#       x: 0.8964733
#       y: 0.53186816
#     }
#     normalized_vertices {
#       x: 0.7076223
#       y: 0.5323077
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: NOTE: Where the rate is dependent on value,shippers are required to state specifically inwriting the agreed or declared value of theproperty. The agreed or declared value of theproperty is hereby specifically stated by theshipper to be not exceeding
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 1650
#       end_index: 1652
#     }
#   }
#   confidence: 0.9552447
#   bounding_poly {
#     vertices {
#       x: 1250
#       y: 1267
#     }
#     vertices {
#       x: 1254
#       y: 1267
#     }
#     vertices {
#       x: 1254
#       y: 1281
#     }
#     vertices {
#       x: 1250
#       y: 1281
#     }
#     normalized_vertices {
#       x: 0.71103525
#       y: 0.5569231
#     }
#     normalized_vertices {
#       x: 0.7133106
#       y: 0.5569231
#     }
#     normalized_vertices {
#       x: 0.7133106
#       y: 0.5630769
#     }
#     normalized_vertices {
#       x: 0.71103525
#       y: 0.5630769
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: $
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 1652
#       end_index: 1662
#     }
#   }
#   confidence: 0.9911676
#   bounding_poly {
#     vertices {
#       x: 1435
#       y: 1267
#     }
#     vertices {
#       x: 1508
#       y: 1266
#     }
#     vertices {
#       x: 1508
#       y: 1284
#     }
#     vertices {
#       x: 1435
#       y: 1285
#     }
#     normalized_vertices {
#       x: 0.8162685
#       y: 0.5569231
#     }
#     normalized_vertices {
#       x: 0.857793
#       y: 0.5564835
#     }
#     normalized_vertices {
#       x: 0.857793
#       y: 0.5643956
#     }
#     normalized_vertices {
#       x: 0.8162685
#       y: 0.5648352
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: per pound
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 1662
#       end_index: 1681
#     }
#   }
#   confidence: 0.98655725
#   bounding_poly {
#     vertices {
#       x: 1247
#       y: 1352
#     }
#     vertices {
#       x: 1432
#       y: 1352
#     }
#     vertices {
#       x: 1432
#       y: 1369
#     }
#     vertices {
#       x: 1247
#       y: 1369
#     }
#     normalized_vertices {
#       x: 0.7093288
#       y: 0.5942857
#     }
#     normalized_vertices {
#       x: 0.814562
#       y: 0.5942857
#     }
#     normalized_vertices {
#       x: 0.814562
#       y: 0.60175824
#     }
#     normalized_vertices {
#       x: 0.7093288
#       y: 0.60175824
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: CHARGES ADVANCED $
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 1681
#       end_index: 1691
#     }
#   }
#   confidence: 0.98762226
#   bounding_poly {
#     vertices {
#       x: 1246
#       y: 1385
#     }
#     vertices {
#       x: 1330
#       y: 1384
#     }
#     vertices {
#       x: 1330
#       y: 1400
#     }
#     vertices {
#       x: 1246
#       y: 1401
#     }
#     normalized_vertices {
#       x: 0.70875996
#       y: 0.60879123
#     }
#     normalized_vertices {
#       x: 0.75654155
#       y: 0.60835165
#     }
#     normalized_vertices {
#       x: 0.75654155
#       y: 0.61538464
#     }
#     normalized_vertices {
#       x: 0.70875996
#       y: 0.61582416
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: REMITT TO
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 1691
#       end_index: 1699
#     }
#   }
#   confidence: 0.99546546
#   bounding_poly {
#     vertices {
#       x: 1378
#       y: 1420
#     }
#     vertices {
#       x: 1446
#       y: 1419
#     }
#     vertices {
#       x: 1446
#       y: 1436
#     }
#     vertices {
#       x: 1378
#       y: 1437
#     }
#     normalized_vertices {
#       x: 0.7838453
#       y: 0.62417585
#     }
#     normalized_vertices {
#       x: 0.8225256
#       y: 0.62373626
#     }
#     normalized_vertices {
#       x: 0.8225256
#       y: 0.6312088
#     }
#     normalized_vertices {
#       x: 0.7838453
#       y: 0.63164836
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: SHIPPER
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 1699
#       end_index: 1705
#     }
#   }
#   confidence: 0.99407345
#   bounding_poly {
#     vertices {
#       x: 1376
#       y: 1447
#     }
#     vertices {
#       x: 1431
#       y: 1447
#     }
#     vertices {
#       x: 1431
#       y: 1462
#     }
#     vertices {
#       x: 1376
#       y: 1462
#     }
#     normalized_vertices {
#       x: 0.78270763
#       y: 0.63604397
#     }
#     normalized_vertices {
#       x: 0.81399316
#       y: 0.63604397
#     }
#     normalized_vertices {
#       x: 0.81399316
#       y: 0.6426374
#     }
#     normalized_vertices {
#       x: 0.78270763
#       y: 0.6426374
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: OTHER
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 1705
#       end_index: 1770
#     }
#   }
#   confidence: 0.99296457
#   bounding_poly {
#     vertices {
#       x: 1260
#       y: 1482
#     }
#     vertices {
#       x: 1477
#       y: 1482
#     }
#     vertices {
#       x: 1477
#       y: 1528
#     }
#     vertices {
#       x: 1260
#       y: 1528
#     }
#     normalized_vertices {
#       x: 0.71672356
#       y: 0.6514286
#     }
#     normalized_vertices {
#       x: 0.8401593
#       y: 0.6514286
#     }
#     normalized_vertices {
#       x: 0.8401593
#       y: 0.6716483
#     }
#     normalized_vertices {
#       x: 0.71672356
#       y: 0.6716483
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: IF OTHER THAN SHIPPER WRITENAME AND ADDRESS INDESCRIPTION COLUMN
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 1770
#       end_index: 1772
#     }
#   }
#   confidence: 0.97049624
#   bounding_poly {
#     vertices {
#       x: 207
#       y: 1517
#     }
#     vertices {
#       x: 211
#       y: 1517
#     }
#     vertices {
#       x: 211
#       y: 1531
#     }
#     vertices {
#       x: 207
#       y: 1531
#     }
#     normalized_vertices {
#       x: 0.11774744
#       y: 0.6668132
#     }
#     normalized_vertices {
#       x: 0.12002275
#       y: 0.6668132
#     }
#     normalized_vertices {
#       x: 0.12002275
#       y: 0.672967
#     }
#     normalized_vertices {
#       x: 0.11774744
#       y: 0.672967
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: 0
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 1772
#       end_index: 1793
#     }
#   }
#   confidence: 0.99500006
#   bounding_poly {
#     vertices {
#       x: 266
#       y: 1515
#     }
#     vertices {
#       x: 458
#       y: 1515
#     }
#     vertices {
#       x: 458
#       y: 1531
#     }
#     vertices {
#       x: 266
#       y: 1531
#     }
#     normalized_vertices {
#       x: 0.1513083
#       y: 0.6659341
#     }
#     normalized_vertices {
#       x: 0.26052332
#       y: 0.6659341
#     }
#     normalized_vertices {
#       x: 0.26052332
#       y: 0.672967
#     }
#     normalized_vertices {
#       x: 0.1513083
#       y: 0.672967
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: TOTAL HANDLING UNITS
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 1793
#       end_index: 1826
#     }
#   }
#   confidence: 0.9944721
#   bounding_poly {
#     vertices {
#       x: 564
#       y: 1514
#     }
#     vertices {
#       x: 888
#       y: 1514
#     }
#     vertices {
#       x: 888
#       y: 1531
#     }
#     vertices {
#       x: 564
#       y: 1531
#     }
#     normalized_vertices {
#       x: 0.3208191
#       y: 0.6654945
#     }
#     normalized_vertices {
#       x: 0.50511944
#       y: 0.6654945
#     }
#     normalized_vertices {
#       x: 0.50511944
#       y: 0.672967
#     }
#     normalized_vertices {
#       x: 0.3208191
#       y: 0.672967
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: TOTAL HAZARDOUS MATERIALS WEIGHT
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 1826
#       end_index: 1831
#     }
#   }
#   confidence: 0.98616827
#   bounding_poly {
#     vertices {
#       x: 982
#       y: 1515
#     }
#     vertices {
#       x: 1010
#       y: 1515
#     }
#     vertices {
#       x: 1010
#       y: 1529
#     }
#     vertices {
#       x: 982
#       y: 1529
#     }
#     normalized_vertices {
#       x: 0.5585893
#       y: 0.6659341
#     }
#     normalized_vertices {
#       x: 0.5745165
#       y: 0.6659341
#     }
#     normalized_vertices {
#       x: 0.5745165
#       y: 0.6720879
#     }
#     normalized_vertices {
#       x: 0.5585893
#       y: 0.6720879
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: 0.00
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 1831
#       end_index: 1844
#     }
#   }
#   confidence: 0.9921815
#   bounding_poly {
#     vertices {
#       x: 767
#       y: 1550
#     }
#     vertices {
#       x: 888
#       y: 1550
#     }
#     vertices {
#       x: 888
#       y: 1566
#     }
#     vertices {
#       x: 767
#       y: 1566
#     }
#     normalized_vertices {
#       x: 0.43629125
#       y: 0.6813187
#     }
#     normalized_vertices {
#       x: 0.50511944
#       y: 0.6813187
#     }
#     normalized_vertices {
#       x: 0.50511944
#       y: 0.68835163
#     }
#     normalized_vertices {
#       x: 0.43629125
#       y: 0.68835163
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: TOTAL WEIGHT
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 1844
#       end_index: 1849
#     }
#   }
#   confidence: 0.9779728
#   bounding_poly {
#     vertices {
#       x: 980
#       y: 1550
#     }
#     vertices {
#       x: 1009
#       y: 1550
#     }
#     vertices {
#       x: 1009
#       y: 1567
#     }
#     vertices {
#       x: 980
#       y: 1567
#     }
#     normalized_vertices {
#       x: 0.55745167
#       y: 0.6813187
#     }
#     normalized_vertices {
#       x: 0.57394767
#       y: 0.6813187
#     }
#     normalized_vertices {
#       x: 0.57394767
#       y: 0.6887912
#     }
#     normalized_vertices {
#       x: 0.55745167
#       y: 0.6887912
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: 0.00
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 1849
#       end_index: 2091
#     }
#   }
#   confidence: 0.99366915
#   bounding_poly {
#     vertices {
#       x: 154
#       y: 1579
#     }
#     vertices {
#       x: 1577
#       y: 1579
#     }
#     vertices {
#       x: 1577
#       y: 1597
#     }
#     vertices {
#       x: 154
#       y: 1597
#     }
#     normalized_vertices {
#       x: 0.087599546
#       y: 0.6940659
#     }
#     normalized_vertices {
#       x: 0.8970421
#       y: 0.6940659
#     }
#     normalized_vertices {
#       x: 0.8970421
#       y: 0.701978
#     }
#     normalized_vertices {
#       x: 0.087599546
#       y: 0.701978
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: "This is to certify that the above named materials are properly classified, described, packaged, marked and labeled and are in proper condition for transportation, according to the applicable regulations of the Department of Transportation".
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 2091
#       end_index: 2102
#     }
#   }
#   confidence: 0.9895593
#   bounding_poly {
#     vertices {
#       x: 164
#       y: 1625
#     }
#     vertices {
#       x: 282
#       y: 1624
#     }
#     vertices {
#       x: 282
#       y: 1643
#     }
#     vertices {
#       x: 164
#       y: 1644
#     }
#     normalized_vertices {
#       x: 0.093287826
#       y: 0.71428573
#     }
#     normalized_vertices {
#       x: 0.16040955
#       y: 0.71384615
#     }
#     normalized_vertices {
#       x: 0.16040955
#       y: 0.72219783
#     }
#     normalized_vertices {
#       x: 0.093287826
#       y: 0.72263736
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: Loose LPNs
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 2102
#       end_index: 2110
#     }
#   }
#   confidence: 0.99391335
#   bounding_poly {
#     vertices {
#       x: 318
#       y: 1625
#     }
#     vertices {
#       x: 382
#       y: 1625
#     }
#     vertices {
#       x: 382
#       y: 1644
#     }
#     vertices {
#       x: 318
#       y: 1644
#     }
#     normalized_vertices {
#       x: 0.18088737
#       y: 0.71428573
#     }
#     normalized_vertices {
#       x: 0.21729238
#       y: 0.71428573
#     }
#     normalized_vertices {
#       x: 0.21729238
#       y: 0.72263736
#     }
#     normalized_vertices {
#       x: 0.18088737
#       y: 0.72263736
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: Pallets
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 2110
#       end_index: 2131
#     }
#   }
#   confidence: 0.99386054
#   bounding_poly {
#     vertices {
#       x: 438
#       y: 1623
#     }
#     vertices {
#       x: 628
#       y: 1624
#     }
#     vertices {
#       x: 628
#       y: 1648
#     }
#     vertices {
#       x: 438
#       y: 1647
#     }
#     normalized_vertices {
#       x: 0.24914676
#       y: 0.7134066
#     }
#     normalized_vertices {
#       x: 0.3572241
#       y: 0.71384615
#     }
#     normalized_vertices {
#       x: 0.3572241
#       y: 0.72439563
#     }
#     normalized_vertices {
#       x: 0.24914676
#       y: 0.72395605
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: Total Handling Units
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 2131
#       end_index: 2147
#     }
#   }
#   confidence: 0.99716437
#   bounding_poly {
#     vertices {
#       x: 685
#       y: 1623
#     }
#     vertices {
#       x: 844
#       y: 1624
#     }
#     vertices {
#       x: 844
#       y: 1649
#     }
#     vertices {
#       x: 685
#       y: 1648
#     }
#     normalized_vertices {
#       x: 0.38964733
#       y: 0.7134066
#     }
#     normalized_vertices {
#       x: 0.480091
#       y: 0.71384615
#     }
#     normalized_vertices {
#       x: 0.480091
#       y: 0.72483516
#     }
#     normalized_vertices {
#       x: 0.38964733
#       y: 0.72439563
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: Single Shipment
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 2147
#       end_index: 2154
#     }
#   }
#   confidence: 0.9942791
#   bounding_poly {
#     vertices {
#       x: 952
#       y: 1625
#     }
#     vertices {
#       x: 1013
#       y: 1625
#     }
#     vertices {
#       x: 1013
#       y: 1645
#     }
#     vertices {
#       x: 952
#       y: 1645
#     }
#     normalized_vertices {
#       x: 0.54152447
#       y: 0.71428573
#     }
#     normalized_vertices {
#       x: 0.57622296
#       y: 0.71428573
#     }
#     normalized_vertices {
#       x: 0.57622296
#       y: 0.72307694
#     }
#     normalized_vertices {
#       x: 0.54152447
#       y: 0.72307694
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: Driver
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 2154
#       end_index: 2159
#     }
#   }
#   confidence: 0.9897005
#   bounding_poly {
#     vertices {
#       x: 1147
#       y: 1626
#     }
#     vertices {
#       x: 1188
#       y: 1626
#     }
#     vertices {
#       x: 1188
#       y: 1644
#     }
#     vertices {
#       x: 1147
#       y: 1644
#     }
#     normalized_vertices {
#       x: 0.652446
#       y: 0.71472526
#     }
#     normalized_vertices {
#       x: 0.6757679
#       y: 0.71472526
#     }
#     normalized_vertices {
#       x: 0.6757679
#       y: 0.72263736
#     }
#     normalized_vertices {
#       x: 0.652446
#       y: 0.72263736
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: Date
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 2159
#       end_index: 2165
#     }
#   }
#   confidence: 0.9928336
#   bounding_poly {
#     vertices {
#       x: 1339
#       y: 1625
#     }
#     vertices {
#       x: 1383
#       y: 1625
#     }
#     vertices {
#       x: 1383
#       y: 1644
#     }
#     vertices {
#       x: 1339
#       y: 1644
#     }
#     normalized_vertices {
#       x: 0.761661
#       y: 0.71428573
#     }
#     normalized_vertices {
#       x: 0.7866894
#       y: 0.71428573
#     }
#     normalized_vertices {
#       x: 0.7866894
#       y: 0.72263736
#     }
#     normalized_vertices {
#       x: 0.761661
#       y: 0.72263736
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: Start
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 2165
#       end_index: 2170
#     }
#   }
#   confidence: 0.9934573
#   bounding_poly {
#     vertices {
#       x: 1515
#       y: 1623
#     }
#     vertices {
#       x: 1558
#       y: 1625
#     }
#     vertices {
#       x: 1557
#       y: 1649
#     }
#     vertices {
#       x: 1514
#       y: 1647
#     }
#     normalized_vertices {
#       x: 0.86177474
#       y: 0.7134066
#     }
#     normalized_vertices {
#       x: 0.88623434
#       y: 0.71428573
#     }
#     normalized_vertices {
#       x: 0.88566554
#       y: 0.72483516
#     }
#     normalized_vertices {
#       x: 0.86120594
#       y: 0.72395605
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: Stop
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 2170
#       end_index: 2172
#     }
#   }
#   confidence: 0.9888844
#   bounding_poly {
#     vertices {
#       x: 227
#       y: 1679
#     }
#     vertices {
#       x: 231
#       y: 1679
#     }
#     vertices {
#       x: 231
#       y: 1694
#     }
#     vertices {
#       x: 227
#       y: 1694
#     }
#     normalized_vertices {
#       x: 0.129124
#       y: 0.73802197
#     }
#     normalized_vertices {
#       x: 0.13139932
#       y: 0.73802197
#     }
#     normalized_vertices {
#       x: 0.13139932
#       y: 0.7446154
#     }
#     normalized_vertices {
#       x: 0.129124
#       y: 0.7446154
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: 2
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 2172
#       end_index: 2175
#     }
#   }
#   confidence: 0.98277974
#   bounding_poly {
#     vertices {
#       x: 349
#       y: 1679
#     }
#     vertices {
#       x: 366
#       y: 1679
#     }
#     vertices {
#       x: 366
#       y: 1694
#     }
#     vertices {
#       x: 349
#       y: 1694
#     }
#     normalized_vertices {
#       x: 0.19852105
#       y: 0.73802197
#     }
#     normalized_vertices {
#       x: 0.20819113
#       y: 0.73802197
#     }
#     normalized_vertices {
#       x: 0.20819113
#       y: 0.7446154
#     }
#     normalized_vertices {
#       x: 0.19852105
#       y: 0.7446154
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: 14
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 2175
#       end_index: 2177
#     }
#   }
#   confidence: 0.9515134
#   bounding_poly {
#     vertices {
#       x: 838
#       y: 1679
#     }
#     vertices {
#       x: 844
#       y: 1679
#     }
#     vertices {
#       x: 844
#       y: 1700
#     }
#     vertices {
#       x: 838
#       y: 1700
#     }
#     normalized_vertices {
#       x: 0.47667804
#       y: 0.73802197
#     }
#     normalized_vertices {
#       x: 0.480091
#       y: 0.73802197
#     }
#     normalized_vertices {
#       x: 0.480091
#       y: 0.74725276
#     }
#     normalized_vertices {
#       x: 0.47667804
#       y: 0.74725276
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: N
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 2177
#       end_index: 2185
#     }
#   }
#   confidence: 0.97043145
#   bounding_poly {
#     vertices {
#       x: 254
#       y: 1733
#     }
#     vertices {
#       x: 318
#       y: 1732
#     }
#     vertices {
#       x: 318
#       y: 1751
#     }
#     vertices {
#       x: 254
#       y: 1752
#     }
#     normalized_vertices {
#       x: 0.14448236
#       y: 0.76175827
#     }
#     normalized_vertices {
#       x: 0.18088737
#       y: 0.7613187
#     }
#     normalized_vertices {
#       x: 0.18088737
#       y: 0.7696703
#     }
#     normalized_vertices {
#       x: 0.14448236
#       y: 0.7701099
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: Truck #
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 2185
#       end_index: 2246
#     }
#   }
#   confidence: 0.9902656
#   bounding_poly {
#     vertices {
#       x: 417
#       y: 1666
#     }
#     vertices {
#       x: 812
#       y: 1666
#     }
#     vertices {
#       x: 812
#       y: 1823
#     }
#     vertices {
#       x: 417
#       y: 1823
#     }
#     normalized_vertices {
#       x: 0.23720136
#       y: 0.7323077
#     }
#     normalized_vertices {
#       x: 0.46188852
#       y: 0.7323077
#     }
#     normalized_vertices {
#       x: 0.46188852
#       y: 0.8013187
#     }
#     normalized_vertices {
#       x: 0.23720136
#       y: 0.8013187
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: CIRCLE16YONEShipper Load & Count DATECIRCLEY N 03/21/2016ONE
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 2246
#       end_index: 2258
#     }
#   }
#   confidence: 0.99170715
#   bounding_poly {
#     vertices {
#       x: 903
#       y: 1734
#     }
#     vertices {
#       x: 1055
#       y: 1734
#     }
#     vertices {
#       x: 1055
#       y: 1755
#     }
#     vertices {
#       x: 903
#       y: 1755
#     }
#     normalized_vertices {
#       x: 0.51365185
#       y: 0.7621978
#     }
#     normalized_vertices {
#       x: 0.60011375
#       y: 0.7621978
#     }
#     normalized_vertices {
#       x: 0.60011375
#       y: 0.7714286
#     }
#     normalized_vertices {
#       x: 0.51365185
#       y: 0.7714286
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: SEAL NUMBER
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 2258
#       end_index: 2279
#     }
#   }
#   confidence: 0.9960221
#   bounding_poly {
#     vertices {
#       x: 1207
#       y: 1734
#     }
#     vertices {
#       x: 1479
#       y: 1734
#     }
#     vertices {
#       x: 1479
#       y: 1756
#     }
#     vertices {
#       x: 1207
#       y: 1756
#     }
#     normalized_vertices {
#       x: 0.68657565
#       y: 0.7621978
#     }
#     normalized_vertices {
#       x: 0.8412969
#       y: 0.7621978
#     }
#     normalized_vertices {
#       x: 0.8412969
#       y: 0.7718681
#     }
#     normalized_vertices {
#       x: 0.68657565
#       y: 0.7718681
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: AUTHORIZED SIGNATURE
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 2279
#       end_index: 2287
#     }
#   }
#   confidence: 0.9933494
#   bounding_poly {
#     vertices {
#       x: 246
#       y: 1787
#     }
#     vertices {
#       x: 331
#       y: 1787
#     }
#     vertices {
#       x: 331
#       y: 1807
#     }
#     vertices {
#       x: 246
#       y: 1807
#     }
#     normalized_vertices {
#       x: 0.13993174
#       y: 0.7854945
#     }
#     normalized_vertices {
#       x: 0.18828213
#       y: 0.7854945
#     }
#     normalized_vertices {
#       x: 0.18828213
#       y: 0.7942857
#     }
#     normalized_vertices {
#       x: 0.13993174
#       y: 0.7942857
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: 4412007
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 2287
#       end_index: 2332
#     }
#   }
#   confidence: 0.9898169
#   bounding_poly {
#     vertices {
#       x: 278
#       y: 1885
#     }
#     vertices {
#       x: 682
#       y: 1882
#     }
#     vertices {
#       x: 683
#       y: 2025
#     }
#     vertices {
#       x: 279
#       y: 2028
#     }
#     normalized_vertices {
#       x: 0.15813424
#       y: 0.82857144
#     }
#     normalized_vertices {
#       x: 0.38794085
#       y: 0.82725275
#     }
#     normalized_vertices {
#       x: 0.38850966
#       y: 0.8901099
#     }
#     normalized_vertices {
#       x: 0.15870307
#       y: 0.8914286
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: Carefully AffixFreight Bill NumberLabel Here
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 2332
#       end_index: 3608
#     }
#   }
#   confidence: 0.995976
#   bounding_poly {
#     vertices {
#       x: 793
#       y: 1838
#     }
#     vertices {
#       x: 1595
#       y: 1838
#     }
#     vertices {
#       x: 1595
#       y: 2066
#     }
#     vertices {
#       x: 793
#       y: 2066
#     }
#     normalized_vertices {
#       x: 0.45108077
#       y: 0.8079121
#     }
#     normalized_vertices {
#       x: 0.907281
#       y: 0.8079121
#     }
#     normalized_vertices {
#       x: 0.907281
#       y: 0.9081319
#     }
#     normalized_vertices {
#       x: 0.45108077
#       y: 0.9081319
#     }
#   }
#   orientation: PAGE_UP
# }
#
# ...
#       y: 0.13802198
#     }
#     normalized_vertices {
#       x: 0.27076223
#       y: 0.14637363
#     }
#     normalized_vertices {
#       x: 0.17463025
#       y: 0.14593406
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: 1601 Whitaker Rd
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 3913
#       end_index: 3921
#     }
#   }
#   confidence: 0.99468577
#   bounding_poly {
#     vertices {
#       x: 911
#       y: 313
#     }
#     vertices {
#       x: 991
#       y: 313
#     }
#     vertices {
#       x: 991
#       y: 332
#     }
#     vertices {
#       x: 911
#       y: 332
#     }
#     normalized_vertices {
#       x: 0.5182025
#       y: 0.13758242
#     }
#     normalized_vertices {
#       x: 0.5637088
#       y: 0.13758242
#     }
#     normalized_vertices {
#       x: 0.5637088
#       y: 0.14593406
#     }
#     normalized_vertices {
#       x: 0.5182025
#       y: 0.14593406
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: Address
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 3921
#       end_index: 3947
#     }
#   }
#   confidence: 0.9935736
#   bounding_poly {
#     vertices {
#       x: 1024
#       y: 312
#     }
#     vertices {
#       x: 1359
#       y: 312
#     }
#     vertices {
#       x: 1359
#       y: 332
#     }
#     vertices {
#       x: 1024
#       y: 332
#     }
#     normalized_vertices {
#       x: 0.5824801
#       y: 0.13714285
#     }
#     normalized_vertices {
#       x: 0.77303755
#       y: 0.13714285
#     }
#     normalized_vertices {
#       x: 0.77303755
#       y: 0.14593406
#     }
#     normalized_vertices {
#       x: 0.5824801
#       y: 0.14593406
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: 2713B SOUTH WOODLAND BLVD
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 3947
#       end_index: 3965
#     }
#   }
#   confidence: 0.9943836
#   bounding_poly {
#     vertices {
#       x: 602
#       y: 348
#     }
#     vertices {
#       x: 765
#       y: 347
#     }
#     vertices {
#       x: 765
#       y: 367
#     }
#     vertices {
#       x: 602
#       y: 368
#     }
#     normalized_vertices {
#       x: 0.34243459
#       y: 0.15296704
#     }
#     normalized_vertices {
#       x: 0.43515357
#       y: 0.15252747
#     }
#     normalized_vertices {
#       x: 0.43515357
#       y: 0.16131867
#     }
#     normalized_vertices {
#       x: 0.34243459
#       y: 0.16175824
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: State or Province
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 3965
#       end_index: 3968
#     }
#   }
#   confidence: 0.9924939
#   bounding_poly {
#     vertices {
#       x: 795
#       y: 348
#     }
#     vertices {
#       x: 811
#       y: 348
#     }
#     vertices {
#       x: 811
#       y: 366
#     }
#     vertices {
#       x: 795
#       y: 366
#     }
#     normalized_vertices {
#       x: 0.45221844
#       y: 0.15296704
#     }
#     normalized_vertices {
#       x: 0.46131968
#       y: 0.15296704
#     }
#     normalized_vertices {
#       x: 0.46131968
#       y: 0.16087912
#     }
#     normalized_vertices {
#       x: 0.45221844
#       y: 0.16087912
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: IN
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 3968
#       end_index: 3975
#     }
#   }
#   confidence: 0.9939466
#   bounding_poly {
#     vertices {
#       x: 1021
#       y: 347
#     }
#     vertices {
#       x: 1106
#       y: 347
#     }
#     vertices {
#       x: 1106
#       y: 367
#     }
#     vertices {
#       x: 1021
#       y: 367
#     }
#     normalized_vertices {
#       x: 0.5807736
#       y: 0.15252747
#     }
#     normalized_vertices {
#       x: 0.629124
#       y: 0.15252747
#     }
#     normalized_vertices {
#       x: 0.629124
#       y: 0.16131867
#     }
#     normalized_vertices {
#       x: 0.5807736
#       y: 0.16131867
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: DELAND
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 3975
#       end_index: 3996
#     }
#   }
#   confidence: 0.99316823
#   bounding_poly {
#     vertices {
#       x: 1334
#       y: 348
#     }
#     vertices {
#       x: 1538
#       y: 348
#     }
#     vertices {
#       x: 1538
#       y: 368
#     }
#     vertices {
#       x: 1334
#       y: 368
#     }
#     normalized_vertices {
#       x: 0.75881684
#       y: 0.15296704
#     }
#     normalized_vertices {
#       x: 0.8748578
#       y: 0.15296704
#     }
#     normalized_vertices {
#       x: 0.8748578
#       y: 0.16175824
#     }
#     normalized_vertices {
#       x: 0.75881684
#       y: 0.16175824
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: State or Province FL
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 3996
#       end_index: 4004
#     }
#   }
#   confidence: 0.9927793
#   bounding_poly {
#     vertices {
#       x: 186
#       y: 348
#     }
#     vertices {
#       x: 218
#       y: 348
#     }
#     vertices {
#       x: 217
#       y: 404
#     }
#     vertices {
#       x: 185
#       y: 404
#     }
#     normalized_vertices {
#       x: 0.105802044
#       y: 0.15296704
#     }
#     normalized_vertices {
#       x: 0.12400455
#       y: 0.15296704
#     }
#     normalized_vertices {
#       x: 0.12343572
#       y: 0.17758241
#     }
#     normalized_vertices {
#       x: 0.10523322
#       y: 0.17758241
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: CityZip
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 4004
#       end_index: 4020
#     }
#   }
#   confidence: 0.99240875
#   bounding_poly {
#     vertices {
#       x: 301
#       y: 347
#     }
#     vertices {
#       x: 387
#       y: 347
#     }
#     vertices {
#       x: 387
#       y: 401
#     }
#     vertices {
#       x: 301
#       y: 401
#     }
#     normalized_vertices {
#       x: 0.17121729
#       y: 0.15252747
#     }
#     normalized_vertices {
#       x: 0.22013652
#       y: 0.15252747
#     }
#     normalized_vertices {
#       x: 0.22013652
#       y: 0.17626373
#     }
#     normalized_vertices {
#       x: 0.17121729
#       y: 0.17626373
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: Plainfield46168
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 4020
#       end_index: 4028
#     }
#   }
#   confidence: 0.9921012
#   bounding_poly {
#     vertices {
#       x: 913
#       y: 347
#     }
#     vertices {
#       x: 948
#       y: 348
#     }
#     vertices {
#       x: 947
#       y: 401
#     }
#     vertices {
#       x: 912
#       y: 400
#     }
#     normalized_vertices {
#       x: 0.51934016
#       y: 0.15252747
#     }
#     normalized_vertices {
#       x: 0.5392491
#       y: 0.15296704
#     }
#     normalized_vertices {
#       x: 0.5386803
#       y: 0.17626373
#     }
#     normalized_vertices {
#       x: 0.51877135
#       y: 0.17582418
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: CityZip
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 4028
#       end_index: 4034
#     }
#   }
#   confidence: 0.99287945
#   bounding_poly {
#     vertices {
#       x: 1027
#       y: 381
#     }
#     vertices {
#       x: 1083
#       y: 381
#     }
#     vertices {
#       x: 1083
#       y: 399
#     }
#     vertices {
#       x: 1027
#       y: 399
#     }
#     normalized_vertices {
#       x: 0.58418655
#       y: 0.16747253
#     }
#     normalized_vertices {
#       x: 0.61604095
#       y: 0.16747253
#     }
#     normalized_vertices {
#       x: 0.61604095
#       y: 0.17538461
#     }
#     normalized_vertices {
#       x: 0.58418655
#       y: 0.17538461
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: 32720
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 4034
#       end_index: 4226
#     }
#   }
#   confidence: 0.99067736
#   bounding_poly {
#     vertices {
#       x: 571
#       y: 427
#     }
#     vertices {
#       x: 1185
#       y: 428
#     }
#     vertices {
#       x: 1185
#       y: 559
#     }
#     vertices {
#       x: 571
#       y: 558
#     }
#     normalized_vertices {
#       x: 0.3248009
#       y: 0.18769231
#     }
#     normalized_vertices {
#       x: 0.6740614
#       y: 0.18813187
#     }
#     normalized_vertices {
#       x: 0.6740614
#       y: 0.24571429
#     }
#     normalized_vertices {
#       x: 0.3248009
#       y: 0.24527472
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: Emergency Contact Number For Hazardous Materials(SPILL, LEAK, FIRE, EXPOSURE or ACCIDENT)1-800-424-9300 (Chemtrec-CCN2285)KIND OF PACKAGING DESCRIPTION OF ARTICLESSPECIAL MARKS AND EXCEPTIONS
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 4226
#       end_index: 4231
#     }
#   }
#   confidence: 0.9456461
#   bounding_poly {
#     vertices {
#       x: 1398
#       y: 523
#     }
#     vertices {
#       x: 1445
#       y: 523
#     }
#     vertices {
#       x: 1445
#       y: 539
#     }
#     vertices {
#       x: 1398
#       y: 539
#     }
#     normalized_vertices {
#       x: 0.79522187
#       y: 0.22989011
#     }
#     normalized_vertices {
#       x: 0.82195675
#       y: 0.22989011
#     }
#     normalized_vertices {
#       x: 0.82195675
#       y: 0.23692308
#     }
#     normalized_vertices {
#       x: 0.79522187
#       y: 0.23692308
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: NMFC
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 4231
#       end_index: 4237
#     }
#   }
#   confidence: 0.99333835
#   bounding_poly {
#     vertices {
#       x: 1517
#       y: 523
#     }
#     vertices {
#       x: 1569
#       y: 523
#     }
#     vertices {
#       x: 1569
#       y: 539
#     }
#     vertices {
#       x: 1517
#       y: 539
#     }
#     normalized_vertices {
#       x: 0.8629124
#       y: 0.22989011
#     }
#     normalized_vertices {
#       x: 0.89249146
#       y: 0.22989011
#     }
#     normalized_vertices {
#       x: 0.89249146
#       y: 0.23692308
#     }
#     normalized_vertices {
#       x: 0.8629124
#       y: 0.23692308
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: CLASS
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 4237
#       end_index: 4251
#     }
#   }
#   confidence: 0.991614
#   bounding_poly {
#     vertices {
#       x: 168
#       y: 523
#     }
#     vertices {
#       x: 254
#       y: 522
#     }
#     vertices {
#       x: 254
#       y: 557
#     }
#     vertices {
#       x: 168
#       y: 558
#     }
#     normalized_vertices {
#       x: 0.09556314
#       y: 0.22989011
#     }
#     normalized_vertices {
#       x: 0.14448236
#       y: 0.22945055
#     }
#     normalized_vertices {
#       x: 0.14448236
#       y: 0.24483517
#     }
#     normalized_vertices {
#       x: 0.09556314
#       y: 0.24527472
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: HANDLINGUNITS
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 4251
#       end_index: 4262
#     }
#   }
#   confidence: 0.98296255
#   bounding_poly {
#     vertices {
#       x: 275
#       y: 523
#     }
#     vertices {
#       x: 368
#       y: 523
#     }
#     vertices {
#       x: 368
#       y: 558
#     }
#     vertices {
#       x: 275
#       y: 558
#     }
#     normalized_vertices {
#       x: 0.15642776
#       y: 0.22989011
#     }
#     normalized_vertices {
#       x: 0.20932879
#       y: 0.22989011
#     }
#     normalized_vertices {
#       x: 0.20932879
#       y: 0.24527472
#     }
#     normalized_vertices {
#       x: 0.15642776
#       y: 0.24527472
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: HMPACKAGES
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 4262
#       end_index: 4266
#     }
#   }
#   confidence: 0.89767957
#   bounding_poly {
#     vertices {
#       x: 389
#       y: 522
#     }
#     vertices {
#       x: 412
#       y: 522
#     }
#     vertices {
#       x: 412
#       y: 557
#     }
#     vertices {
#       x: 389
#       y: 557
#     }
#     normalized_vertices {
#       x: 0.22127418
#       y: 0.22945055
#     }
#     normalized_vertices {
#       x: 0.23435722
#       y: 0.22945055
#     }
#     normalized_vertices {
#       x: 0.23435722
#       y: 0.24483517
#     }
#     normalized_vertices {
#       x: 0.22127418
#       y: 0.24483517
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: HMX
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 4266
#       end_index: 4280
#     }
#   }
#   confidence: 0.9761986
#   bounding_poly {
#     vertices {
#       x: 1256
#       y: 523
#     }
#     vertices {
#       x: 1341
#       y: 523
#     }
#     vertices {
#       x: 1341
#       y: 557
#     }
#     vertices {
#       x: 1256
#       y: 557
#     }
#     normalized_vertices {
#       x: 0.7144482
#       y: 0.22989011
#     }
#     normalized_vertices {
#       x: 0.7627986
#       y: 0.22989011
#     }
#     normalized_vertices {
#       x: 0.7627986
#       y: 0.24483517
#     }
#     normalized_vertices {
#       x: 0.7144482
#       y: 0.24483517
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: WEIGHT INLBS.
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 4280
#       end_index: 4304
#     }
#   }
#   confidence: 0.9899861
#   bounding_poly {
#     vertices {
#       x: 1310
#       y: 571
#     }
#     vertices {
#       x: 1538
#       y: 572
#     }
#     vertices {
#       x: 1538
#       y: 590
#     }
#     vertices {
#       x: 1310
#       y: 589
#     }
#     normalized_vertices {
#       x: 0.74516493
#       y: 0.25098902
#     }
#     normalized_vertices {
#       x: 0.8748578
#       y: 0.25142857
#     }
#     normalized_vertices {
#       x: 0.8748578
#       y: 0.25934067
#     }
#     normalized_vertices {
#       x: 0.74516493
#       y: 0.2589011
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: (SUBJECT TO CORRECTION)
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 4304
#       end_index: 4312
#     }
#   }
#   confidence: 0.97239906
#   bounding_poly {
#     vertices {
#       x: 418
#       y: 610
#     }
#     vertices {
#       x: 496
#       y: 610
#     }
#     vertices {
#       x: 496
#       y: 634
#     }
#     vertices {
#       x: 418
#       y: 634
#     }
#     normalized_vertices {
#       x: 0.2377702
#       y: 0.26813188
#     }
#     normalized_vertices {
#       x: 0.2821388
#       y: 0.26813188
#     }
#     normalized_vertices {
#       x: 0.2821388
#       y: 0.2786813
#     }
#     normalized_vertices {
#       x: 0.2377702
#       y: 0.2786813
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: Truck #
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 4312
#       end_index: 4317
#     }
#   }
#   confidence: 0.9913688
#   bounding_poly {
#     vertices {
#       x: 900
#       y: 610
#     }
#     vertices {
#       x: 967
#       y: 610
#     }
#     vertices {
#       x: 967
#       y: 632
#     }
#     vertices {
#       x: 900
#       y: 632
#     }
#     normalized_vertices {
#       x: 0.51194537
#       y: 0.26813188
#     }
#     normalized_vertices {
#       x: 0.5500569
#       y: 0.26813188
#     }
#     normalized_vertices {
#       x: 0.5500569
#       y: 0.2778022
#     }
#     normalized_vertices {
#       x: 0.51194537
#       y: 0.2778022
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: DATE
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 4317
#       end_index: 4329
#     }
#   }
#   confidence: 0.9929025
#   bounding_poly {
#     vertices {
#       x: 1261
#       y: 610
#     }
#     vertices {
#       x: 1448
#       y: 610
#     }
#     vertices {
#       x: 1448
#       y: 634
#     }
#     vertices {
#       x: 1261
#       y: 634
#     }
#     normalized_vertices {
#       x: 0.71729237
#       y: 0.26813188
#     }
#     normalized_vertices {
#       x: 0.82366323
#       y: 0.26813188
#     }
#     normalized_vertices {
#       x: 0.82366323
#       y: 0.2786813
#     }
#     normalized_vertices {
#       x: 0.71729237
#       y: 0.2786813
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: SEAL NUMBER
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 4329
#       end_index: 4337
#     }
#   }
#   confidence: 0.9943005
#   bounding_poly {
#     vertices {
#       x: 415
#       y: 658
#     }
#     vertices {
#       x: 503
#       y: 658
#     }
#     vertices {
#       x: 503
#       y: 679
#     }
#     vertices {
#       x: 415
#       y: 679
#     }
#     normalized_vertices {
#       x: 0.2360637
#       y: 0.28923076
#     }
#     normalized_vertices {
#       x: 0.2861206
#       y: 0.28923076
#     }
#     normalized_vertices {
#       x: 0.2861206
#       y: 0.29846153
#     }
#     normalized_vertices {
#       x: 0.2360637
#       y: 0.29846153
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: 4412007
#
# layout {
#   text_anchor {
#     text_segments {
#       start_index: 4337
#       end_index: 4348
#     }
#   }
#   confidence: 0.99139684
#   bounding_poly {
#     vertices {
#       x: 883
#       y: 657
#     }
#     vertices {
#       x: 989
#       y: 656
#     }
#     vertices {
#       x: 989
#       y: 676
#     }
#     vertices {
#       x: 883
#       y: 677
#     }
#     normalized_vertices {
#       x: 0.5022753
#       y: 0.2887912
#     }
#     normalized_vertices {
#       x: 0.5625711
#       y: 0.28835166
#     }
#     normalized_vertices {
#       x: 0.5625711
#       y: 0.29714286
#     }
#     normalized_vertices {
#       x: 0.5022753
#       y: 0.29758242
#     }
#   }
#   orientation: PAGE_UP
# }
#
# Paragraph text: 03/21/2016
